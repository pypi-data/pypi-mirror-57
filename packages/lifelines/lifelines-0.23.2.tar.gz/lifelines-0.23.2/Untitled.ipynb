# %%
wf = WeibullAFTFitter().fit(rossi, 'week', 'arrest')

# %%
wf.print_summary(4)
# Out:
# <table border="1" class="dataframe">
#
#   <tbody>
#     <tr>
#       <th>model</th>
#       <td>WeibullAFTFitter</td>
#     </tr>
#     <tr>
#       <th>duration col</th>
#       <td>'week'</td>
#     </tr>
#     <tr>
#       <th>event col</th>
#       <td>'arrest'</td>
#     </tr>
#     <tr>
#       <th>number of observations</th>
#       <td>432</td>
#     </tr>
#     <tr>
#       <th>number of events observed</th>
#       <td>114</td>
#     </tr>
#     <tr>
#       <th>log-likelihood</th>
#       <td>-679.9166</td>
#     </tr>
#     <tr>
#       <th>time fit was run</th>
#       <td>2019-11-16 19:13:18 UTC</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>coef</th>
#       <th>exp(coef)</th>
#       <th>se(coef)</th>
#       <th>coef lower 95%</th>
#       <th>coef upper 95%</th>
#       <th>exp(coef) lower 95%</th>
#       <th>exp(coef) upper 95%</th>
# ...
